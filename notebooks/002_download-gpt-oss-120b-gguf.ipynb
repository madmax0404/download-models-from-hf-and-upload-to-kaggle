# %%
import os, kagglehub
from huggingface_hub import snapshot_download

# %%
kagglehub.login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://www.kaggle.com/static/images/site-logo.png\nalt=\'Kaggle…

# %%
local_dir = '../model'

# %%
snapshot_download(
    repo_id="unsloth/gpt-oss-120b-GGUF",
    local_dir=local_dir,
    force_download=True,
    allow_patterns=[
        '.gitattributes',
        'config.json',
        'params',
        'template',
        'UD-Q4_K_XL/gpt-oss-120b-UD-Q4_K_XL-00002-of-00002.gguf',
        'UD-Q4_K_XL/gpt-oss-120b-UD-Q4_K_XL-00001-of-00002.gguf',
    ],
)
# Out:
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 6 files:   0%|          | 0/6 [00:00<?, ?it/s]
# '/workspace/download-models-from-hf-and-upload-to-kaggle/model'

# %%
handle = 'max6296/unsloth-gpt-oss-120b-4bit/GGUF/default'

# %%
kagglehub.model_upload(handle, local_dir)
# Out:
# Uploading Model https://www.kaggle.com/models/max6296/unsloth-gpt-oss-120b-4bit/GGUF/default ...
# Model 'unsloth-gpt-oss-120b-4bit' does not exist or access is forbidden for user 'max6296'. Creating or handling Model...
# Model 'unsloth-gpt-oss-120b-4bit' Created.
# Starting upload for file ../model/.gitattributes
# Uploading: 100%|██████████| 4.35k/4.35k [00:00<00:00, 11.4kB/s]
# Upload successful: ../model/.gitattributes (4KB)
# Starting upload for file ../model/config.json
# Uploading: 100%|██████████| 2.11k/2.11k [00:00<00:00, 5.30kB/s]
# Upload successful: ../model/config.json (2KB)
# Starting upload for file ../model/params
# Uploading: 100%|██████████| 149/149 [00:00<00:00, 407B/s]
# Upload successful: ../model/params (149B)
# Starting upload for file ../model/template
# Uploading: 100%|██████████| 7.36k/7.36k [00:00<00:00, 19.9kB/s]
# Upload successful: ../model/template (7KB)
# Starting upload for file ../model/UD-Q4_K_XL/gpt-oss-120b-UD-Q4_K_XL-00002-of-00002.gguf
# Uploading: 100%|██████████| 13.1G/13.1G [01:31<00:00, 143MB/s]
# Upload successful: ../model/UD-Q4_K_XL/gpt-oss-120b-UD-Q4_K_XL-00002-of-00002.gguf (12GB)
# Starting upload for file ../model/UD-Q4_K_XL/gpt-oss-120b-UD-Q4_K_XL-00001-of-00002.gguf
# Uploading: 100%|██████████| 49.9G/49.9G [04:18<00:00, 193MB/s]
# Upload successful: ../model/UD-Q4_K_XL/gpt-oss-120b-UD-Q4_K_XL-00001-of-00002.gguf (46GB)
# Your model instance has been created.
# Files are being processed...
# See at: https://www.kaggle.com/models/max6296/unsloth-gpt-oss-120b-4bit/GGUF/default
