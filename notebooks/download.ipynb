# %%
import os, kagglehub
from huggingface_hub import snapshot_download

# %%
kagglehub.login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://www.kaggle.com/static/images/site-logo.png\nalt=\'Kaggle…

# %%
local_dir = '../model'

# %%
snapshot_download(
    repo_id="cpatonn/Qwen3-Next-80B-A3B-Instruct-AWQ-4bit",
    local_dir=local_dir,
    force_download=True,
    # allow_patterns=[
    #     "config.json",
    #     "generation_config.json",
    #     "tokenizer.json",
    #     "tokenizer_config.json",
    #     "special_tokens_map.json",
    #     "model.safetensors.index.json",
    #     "model-*.safetensors",
    #     "chat_template.jinja"
    # ],
)
print("downloaded to:", local_dir)
# Out:
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 23 files:   0%|          | 0/23 [00:00<?, ?it/s]
# downloaded to: ../model

# %%
handle = 'max6296/captonn-qwen3-next-80b-a3b-instruct-awq-4bit/transformers/default'

# %%
kagglehub.model_upload(handle, local_dir)
# Out:
# Uploading Model https://www.kaggle.com/models/max6296/captonn-qwen3-next-80b-a3b-instruct-awq-4bit/transformers/default ...
# Model 'captonn-qwen3-next-80b-a3b-instruct-awq-4bit' does not exist or access is forbidden for user 'max6296'. Creating or handling Model...
# Model 'captonn-qwen3-next-80b-a3b-instruct-awq-4bit' Created.
# Starting upload for file ../model/config.json
# Uploading: 100%|██████████| 22.2k/22.2k [00:00<00:00, 62.7kB/s]
# Upload successful: ../model/config.json (22KB)
# Starting upload for file ../model/generation_config.json
# Uploading: 100%|██████████| 217/217 [00:00<00:00, 268B/s]
# Upload successful: ../model/generation_config.json (217B)
# Starting upload for file ../model/.gitattributes
# Uploading: 100%|██████████| 1.64k/1.64k [00:00<00:00, 2.02kB/s]
# Upload successful: ../model/.gitattributes (2KB)
# Starting upload for file ../model/chat_template.jinja
# Uploading: 100%|██████████| 2.63k/2.63k [00:01<00:00, 2.57kB/s]
# Upload successful: ../model/chat_template.jinja (3KB)
# Starting upload for file ../model/added_tokens.json
# Uploading: 100%|██████████| 707/707 [00:00<00:00, 984B/s]
# Upload successful: ../model/added_tokens.json (707B)
# Starting upload for file ../model/README.md
# Uploading: 100%|██████████| 18.0k/18.0k [00:00<00:00, 48.0kB/s]
# Upload successful: ../model/README.md (18KB)
# Starting upload for file ../model/merges.txt
# Uploading: 100%|██████████| 1.67M/1.67M [00:00<00:00, 1.81MB/s]
# Upload successful: ../model/merges.txt (2MB)
# Starting upload for file ../model/model-00006-of-00010.safetensors
# Uploading: 100%|██████████| 5.37G/5.37G [00:43<00:00, 123MB/s]
# Upload successful: ../model/model-00006-of-00010.safetensors (5GB)
# Starting upload for file ../model/model-00001-of-00010.safetensors
# Uploading: 100%|██████████| 5.37G/5.37G [01:03<00:00, 84.5MB/s]
# Upload successful: ../model/model-00001-of-00010.safetensors (5GB)
# Starting upload for file ../model/model-00005-of-00010.safetensors
# Uploading: 100%|██████████| 5.37G/5.37G [01:02<00:00, 85.9MB/s]
# Upload successful: ../model/model-00005-of-00010.safetensors (5GB)
# Starting upload for file ../model/model-00004-of-00010.safetensors
# Uploading: 100%|██████████| 5.37G/5.37G [00:36<00:00, 149MB/s]
# Upload successful: ../model/model-00004-of-00010.safetensors (5GB)
# Starting upload for file ../model/model.safetensors.index.json
# Uploading: 100%|██████████| 22.0M/22.0M [00:00<00:00, 32.6MB/s]
# Upload successful: ../model/model.safetensors.index.json (21MB)
# Starting upload for file ../model/recipe.yaml
# Uploading: 100%|██████████| 1.58k/1.58k [00:00<00:00, 4.31kB/s]
# Upload successful: ../model/recipe.yaml (2KB)
# Starting upload for file ../model/special_tokens_map.json
# Uploading: 100%|██████████| 613/613 [00:00<00:00, 1.73kB/s]
# Upload successful: ../model/special_tokens_map.json (613B)
# Starting upload for file ../model/tokenizer_config.json
# Uploading: 100%|██████████| 5.41k/5.41k [00:00<00:00, 15.2kB/s]
# Upload successful: ../model/tokenizer_config.json (5KB)
# Starting upload for file ../model/vocab.json
# Uploading: 100%|██████████| 2.78M/2.78M [00:00<00:00, 5.56MB/s]
# Upload successful: ../model/vocab.json (3MB)
# Starting upload for file ../model/model-00008-of-00010.safetensors
# Uploading: 100%|██████████| 5.37G/5.37G [00:41<00:00, 129MB/s]
# Upload successful: ../model/model-00008-of-00010.safetensors (5GB)
# Starting upload for file ../model/tokenizer.json
# Uploading: 100%|██████████| 11.4M/11.4M [00:00<00:00, 20.3MB/s]
# Upload successful: ../model/tokenizer.json (11MB)
# Starting upload for file ../model/model-00007-of-00010.safetensors
# Uploading: 100%|██████████| 5.37G/5.37G [00:37<00:00, 144MB/s]
# Upload successful: ../model/model-00007-of-00010.safetensors (5GB)
# Starting upload for file ../model/model-00003-of-00010.safetensors
# Uploading: 100%|██████████| 5.37G/5.37G [00:45<00:00, 118MB/s]
# Upload successful: ../model/model-00003-of-00010.safetensors (5GB)
# Starting upload for file ../model/model-00002-of-00010.safetensors
# Uploading: 100%|██████████| 5.37G/5.37G [00:36<00:00, 146MB/s]
# Upload successful: ../model/model-00002-of-00010.safetensors (5GB)
# Starting upload for file ../model/model-00010-of-00010.safetensors
# Uploading: 100%|██████████| 887M/887M [00:06<00:00, 127MB/s]
# Upload successful: ../model/model-00010-of-00010.safetensors (846MB)
# Starting upload for file ../model/model-00009-of-00010.safetensors
# Uploading: 100%|██████████| 5.37G/5.37G [00:44<00:00, 120MB/s]
# Upload successful: ../model/model-00009-of-00010.safetensors (5GB)
# Your model instance has been created.
# Files are being processed...
# See at: https://www.kaggle.com/models/max6296/captonn-qwen3-next-80b-a3b-instruct-awq-4bit/transformers/default
